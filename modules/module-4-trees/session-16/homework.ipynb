# %% [markdown]
# # Session 16 · Homework — See Overfitting, Then Explain It
#
# The module's conceptual capstone homework. ✏️ marks cells for you; the notebook runs
# untouched. **Submit** with ✏️ cells filled.

# %% [markdown]
# ## Setup

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.tree import DecisionTreeClassifier, plot_tree
from sklearn.model_selection import train_test_split

df = pd.read_csv("../../../datasets/anchor/student_habits.csv")
habits = ["study_hours_per_week","attendance_pct","sleep_hours_per_night","screen_time_hours_per_day","practice_sessions_per_week"]
X, y = df[habits], df['passed']
X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.3, random_state=42, stratify=y)
print('train students:', len(y_train), '  test students:', len(y_test))

# %% [markdown]
# ## Part 1 · Rebuild the twin-curve plot

# %%
depths = list(range(1, 16)) + [None]        # 1..15, then unlimited
rows = []
for d in depths:
    t = DecisionTreeClassifier(max_depth=d, random_state=0).fit(X_train, y_train)
    rows.append({'max_depth': (99 if d is None else d),   # 99 = 'unlimited' on the x-axis
                 'label': ('none' if d is None else str(d)),
                 'train_acc': t.score(X_train, y_train),
                 'test_acc':  t.score(X_test,  y_test)})
curve = pd.DataFrame(rows)

# %%
fig, ax = plt.subplots(figsize=(10, 6))
ax.plot(curve['max_depth'], curve['train_acc'], 'o-', color='tab:red', label='training')
ax.plot(curve['max_depth'], curve['test_acc'], 'o-', color='tab:blue', label='test')
ax.set_xlabel('max_depth  (99 = unlimited)'); ax.set_ylabel('accuracy')
ax.set_title('Train vs test accuracy vs depth'); ax.legend(); ax.grid(alpha=0.3)
plt.tight_layout(); plt.show()
print(curve[['label','train_acc','test_acc']].round(3).to_string(index=False))

# %% [markdown]
# ## Part 2 · The unlimited tree's two accuracies
#
# Report both accuracies for the unlimited tree. **✏️ Then answer:** which is the honest
# measure of how good the model is, and why?

# %%
full_tree = DecisionTreeClassifier(max_depth=None, random_state=0).fit(X_train, y_train)
print('training accuracy:', round(full_tree.score(X_train, y_train), 3))
print('test accuracy    :', round(full_tree.score(X_test, y_test), 3))

# %% [markdown]
# *(Which is the honest measure, and why? Answer here, replacing this line.)*

# %% [markdown]
# ## Part 3 · Choose the depth to ship
#
# **✏️ Fill in** the peak depth, then justify shipping it over the deepest tree — in terms
# of **new students**.

# %%
peak = curve.loc[curve['test_acc'].idxmax()]
print('peak of test curve at max_depth =', peak['label'],
      ' (test acc', round(peak['test_acc'],3), ')')

# ✏️ set this to the depth you would ship, then explain below
depth_to_ship = ...
print('I would ship max_depth =', depth_to_ship)

# %% [markdown]
# *(Why ship that depth and not the deepest tree? Answer in terms of new students.)*

# %% [markdown]
# ## Part 4 · ✏️ Explain overfitting (4–5 sentences)
#
# In your own words, explain overfitting. Your answer **must**:
# 1. use the phrase **"memorising vs learning"** (from Session 1),
# 2. say **how you would detect** overfitting (what would you measure?),
# 3. name **one other place in this course** where the same danger applies
#    (e.g. KNN's `k` from Session 9).
#
# *(Write your explanation here, replacing this line.)*
