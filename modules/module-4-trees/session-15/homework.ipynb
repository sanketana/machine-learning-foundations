# %% [markdown]
# # Session 15 · Homework — Grow the Knob, Read the Ranking
#
# ✏️ marks cells for you; the notebook runs untouched. **Submit** with ✏️ cells filled.

# %% [markdown]
# ## Setup

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.tree import DecisionTreeClassifier, export_text, plot_tree
from sklearn.model_selection import train_test_split

df = pd.read_csv("../../../datasets/anchor/student_habits.csv")
habits = ["study_hours_per_week","attendance_pct","sleep_hours_per_night","screen_time_hours_per_day","practice_sessions_per_week"]
X, y = df[habits], df['passed']
X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.3, random_state=42, stratify=y)
print('train:', len(y_train), ' test:', len(y_test))

# %% [markdown]
# ## Part 1 · Depth sweep (1–4): train vs test
#
# Fit trees at depths 1, 2, 3, 4; build a train-vs-test accuracy table.

# %%
rows = []
for d in [1, 2, 3, 4]:
    t = DecisionTreeClassifier(max_depth=d, random_state=0).fit(X_train, y_train)
    rows.append({'max_depth': d,
                 'train_acc': round(t.score(X_train, y_train), 3),
                 'test_acc':  round(t.score(X_test, y_test), 3)})
sweep = pd.DataFrame(rows)
print(sweep.to_string(index=False))

# %% [markdown]
# **✏️ One sentence:** what happens to the **train** column as depth grows, and what
# happens to the **test** column?
#
# *(Answer here, replacing this line.)*

# %% [markdown]
# ## Part 2 · Feature importance of the depth-3 tree

# %%
tree3 = DecisionTreeClassifier(max_depth=3, random_state=0).fit(X_train, y_train)
importance = pd.Series(tree3.feature_importances_, index=habits).sort_values(ascending=False)
print(importance.round(3).to_string())

fig, ax = plt.subplots(figsize=(8, 3.5))
importance[::-1].plot.barh(ax=ax, color='steelblue')
ax.set_xlabel('importance'); ax.set_title('Feature importance (depth-3)')
plt.tight_layout(); plt.show()

# %% [markdown]
# ## Part 3 · Most-used vs ignored
#
# **✏️ Fill in** the two feature names below. Then answer: an ignored feature (importance
# ≈ 0) isn't necessarily *unrelated* to passing — why not? (1–2 sentences.)

# %%
# ✏️ from the ranking above
most_used = '...'   # the feature with the highest importance
ignored   = '...'   # a feature with importance ~0.00
print('most used:', most_used)
print('ignored :', ignored)

# %% [markdown]
# *(Why an ignored feature isn't necessarily unrelated — answer here.)*

# %% [markdown]
# ## Part 4 · ✏️ Note to a school counsellor (3–4 sentences)
#
# Write a short, plain-language note stating **what drives** the model's prediction and
# **what barely matters**, and name one feature you'd be *uncomfortable* letting such a
# model rely on (and why).
#
# *(Write your note here, replacing this line.)*
