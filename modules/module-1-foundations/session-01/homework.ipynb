# %% [markdown]
# # Session 1 Homework · Spotting the Learning
#
# **Expected time:** 30–45 minutes · **Bring questions** — next session opens with homework review.
#
# **Done means:**
#
# - all five exercises attempted
# - Exercise 2: both framings labeled correctly (features vs label)
# - Exercise 3: your function runs on all three test cases
# - Exercise 4: a reflection of at least three sentences that uses *memorizing* and *learning* correctly
#
# No machine learning library needed — this homework is about seeing ML clearly, which matters more than running it.

# %% [markdown]
# ## Exercise 1 · Three scenarios
#
# For each scenario answer three things: **(i)** what is being predicted or found (the label, if there is one), **(ii)** what information is available (the features), **(iii)** supervised or unsupervised?
#
# - **A.** A cricket app predicts whether a batter will score a half-century in today's match, using their past innings: balls faced, strike rate, opposition, venue.
# - **B.** Your phone keyboard suggests the next word while you type.
# - **C.** A streaming service groups its users into listening-style segments. It has play history but no predefined segments.
#
# ✏️ *Your answers:*
#
# **A:** (i) … (ii) … (iii) …
#
# **B:** (i) … (ii) … (iii) …
#
# **C:** (i) … (ii) … (iii) …

# %% [markdown]
# ## Exercise 2 · One table, two questions
#
# Run the cell below to load a small table about apps on someone's phone.

# %%
import pandas as pd

apps = pd.DataFrame({
    "app_name":              ["ChatPal", "PhotoSnap", "StudyDeck", "GameBox", "NewsBite", "FitTrack"],
    "minutes_used_per_day":  [95, 40, 25, 120, 8, 15],
    "notifications_per_day": [60, 12, 5, 30, 25, 10],
    "opens_per_day":         [40, 9, 4, 18, 3, 6],
    "kept_installed":        ["yes", "yes", "yes", "yes", "no", "no"],
})
apps

# %% [markdown]
# Two different prediction questions about the **same table**:
#
# **Question 1:** predict whether an app stays installed (`kept_installed`).
#
# **Question 2:** predict how many minutes per day an app gets used (`minutes_used_per_day`).
#
# ✏️ For each question, list the features and the label. Then answer: what changed between the two questions — the data, or the way we looked at it?
#
# *Question 1 — features: … label: …*
#
# *Question 2 — features: … label: …*
#
# *What changed: …*

# %% [markdown]
# ## Exercise 3 · Be the rules
#
# Write your own rule-based "model": will you reply to a message quickly? Add 2–3 `if` rules to the function, then run the test cell.

# %%
def will_i_reply_quickly(sender_is_friend, message_has_question, hour_of_day):
    """Return True if you'd reply within 5 minutes, using YOUR rules.

    sender_is_friend:     True / False
    message_has_question: True / False
    hour_of_day:          0-23
    """
    # ✏️ TODO: replace the line below with 2-3 if-rules of your own.
    return False


# Test cases — your function should run on all three:
print("Friend asks a question at 5pm: ", will_i_reply_quickly(True,  True,  17))
print("Stranger, no question, 11pm:   ", will_i_reply_quickly(False, False, 23))
print("Friend, no question, 7am:      ", will_i_reply_quickly(True,  False, 7))

# %% [markdown]
# ✏️ Now break your own model: describe one realistic situation where your rules give the wrong answer.
#
# *My rules fail when: …*

# %% [markdown]
# ## Exercise 4 · The memorizer, again
#
# The cell below builds a model that memorizes which movies you liked. Run it, then add one *new* movie title to the `new_movies` list and run it again.

# %%
liked_movies = {
    "Sky Pirates":      "liked",
    "The Long Walk":    "did not like",
    "Robot Summer":     "liked",
    "Quiet Harbour":    "did not like",
}

def movie_memorizer(title):
    if title in liked_movies:
        return liked_movies[title]
    return "??? (never seen this title)"

# ✏️ TODO: add one more made-up movie title to this list, then re-run.
new_movies = ["Chase the Dawn", "Sky Pirates 2"]

for title in new_movies:
    print(f"{title:15s} -> {movie_memorizer(title)}")

# %% [markdown]
# ✏️ Reflection (at least three sentences, using *memorizing* and *learning* correctly):
#
# The memorizer knows your taste perfectly for movies you've rated — so why is it useless for choosing what to watch next? What would a model that *learned* your taste use instead of titles?
#
# *Your reflection:*
#
# …

# %% [markdown]
# ## Exercise 5 · ML in your life (open-ended)
#
# Pick **one** system you actually use that you suspect runs on machine learning — recommendations, photo face-grouping, autocorrect, spam filtering, a game's matchmaking, anything.
#
# ✏️ Describe it in about five sentences:
#
# 1. What does it predict or find? ("predict ___ from ___" if supervised)
# 2. What data does it learn from, and where did that data come from?
# 3. What are the features, roughly?
# 4. Supervised or unsupervised — and how can you tell?
# 5. One time it was wrong about you, and your best guess why.
#
# *Your answer:*
#
# …
