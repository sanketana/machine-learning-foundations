# %% [markdown]
# # Session 9 · Homework — A KNN Spam Filter
#
# **Machine Learning Foundations · Sanketana School of Code**
#
# You built a pass/fail classifier in class. Now build a second one in a completely different domain: **spam vs not-spam**, using the same KNN workflow.
#
# `spam_features.csv` describes 800 messages with features like how often the words *free* and *offer* appear, the number of links and exclamation marks, the message length, and whether the sender is in your contacts. The label is `is_spam` (1 = spam). About **40% are spam** — balanced enough that **accuracy** is an honest judge here. (That changes in Session 12, on purpose.)
#
# **Your goal:** train a KNN classifier, report its **test accuracy**, try a few values of k, and choose one — backed by a number.

# %% [markdown]
# ## Step 1 · Load and look

# %%
import pandas as pd
import numpy as np
from sklearn.neighbors import KNeighborsClassifier
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split

spam = pd.read_csv("../../../datasets/secondary/spam_features.csv")
print("messages:", len(spam))
print("spam rate:", round(spam["is_spam"].mean(), 3))
spam.head()

# %% [markdown]
# ## Step 2 · Scale, split, and fit KNN
#
# KNN measures **distance**, so scale the features first (`num_links`, `message_length_words` and friends are on very different scales). Then hide a test set, fit, and score **accuracy** — a named metric.

# %%
feature_cols = [c for c in spam.columns if c != "is_spam"]
X = spam[feature_cols].values
y = spam["is_spam"].values

# ✏️ TODO: hold out 25% as a test set (stratify by y).
X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.25, random_state=42, stratify=y)

# ✏️ TODO: scale using the training set only.
scaler = StandardScaler().fit(X_train)
X_train_s = scaler.transform(X_train)
X_test_s = scaler.transform(X_test)

# ✏️ TODO: fit KNN (k=5) and report test accuracy.
knn = KNeighborsClassifier(n_neighbors=5).fit(X_train_s, y_train)
print("test accuracy (k=5):", round(knn.score(X_test_s, y_test), 3))

# %% [markdown]
# ## Step 3 · Try three values of k
#
# Fit KNN for at least **three** values of k (e.g. 1, 5, 15). Report both training and test accuracy for each. Watch what k=1 does on the **training** set.

# %%
for k in [1, 5, 15]:
    m = KNeighborsClassifier(n_neighbors=k).fit(X_train_s, y_train)
    tr = m.score(X_train_s, y_train)
    te = m.score(X_test_s, y_test)
    print(f"k={k:2d}: train {tr:.3f}  test {te:.3f}")

# %% [markdown]
# ## Step 4 · ✏️ Your verdict
#
# Answer both, in one sentence each:
#
# 1. **Which k would you ship, and what test accuracy justifies it?** (A choice of k without a number does not pass — that's the module rule.)
# 2. **Why did you scale the features before running KNN?**
#
# *Your answers here:*
#
# 1.
# 2.

# %% [markdown]
# *Check your work against `homework-solutions.ipynb` after you've attempted every part.*
